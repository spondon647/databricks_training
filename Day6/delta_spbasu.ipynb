# %% [markdown]
# #delta internals

# %%
# %sql
use catalog lakehouse

# %%
# %sql
create schema lakehouse.spondon managed location 'abfss://raw@adlsnaval123.dfs.core.windows.net/lakehouse/spondon'

# %%
# %sql
create table lakehouse.spondon.demo (id int, name string)
